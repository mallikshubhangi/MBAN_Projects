# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#Step 1: Reading the sales data
sales_df = pd.read_csv('/Users/shubhangimallik/Downloads/sales_data.csv')

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     947 non-null    object
#  1   Region      946 non-null    object
#  2   Price       945 non-null    float64
#  3   Units Sold  946 non-null    float64
#  4   Sale Date   1050 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 41.1+ KB

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     947 non-null    object
#  1   Region      946 non-null    object
#  2   Price       945 non-null    float64
#  3   Units Sold  946 non-null    float64
#  4   Sale Date   1050 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 41.1+ KB

# %%
sales_df.describe()
# Out:
#              Price  Units Sold
# count   945.000000  946.000000
# mean    107.598688   10.048626
# std     124.020322    3.172261
# min       0.200000    2.000000
# 25%      29.430000    8.000000
# 50%      78.130000   10.000000
# 75%     142.570000   12.000000
# max    2143.300000   22.000000

# %%
sales_df['Product'].fillna('Other', inplace=True)

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     1050 non-null   object
#  1   Region      946 non-null    object
#  2   Price       945 non-null    float64
#  3   Units Sold  946 non-null    float64
#  4   Sale Date   1050 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 41.1+ KB

# %%
sales_df['Region'].fillna('Unknown', inplace=True)

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     1050 non-null   object
#  1   Region      1050 non-null   object
#  2   Price       945 non-null    float64
#  3   Units Sold  946 non-null    float64
#  4   Sale Date   1050 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 41.1+ KB

# %%
sales_df['Price'].fillna(sales_df.groupby('Product')['Price'].transform('mean'), inplace=True)

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     1050 non-null   object
#  1   Region      1050 non-null   object
#  2   Price       1050 non-null   float64
#  3   Units Sold  946 non-null    float64
#  4   Sale Date   1050 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 41.1+ KB

# %%
sales_df['Units Sold'].fillna(sales_df.groupby('Product')['Units Sold'].transform('mean'), inplace=True)

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     1050 non-null   object
#  1   Region      1050 non-null   object
#  2   Price       1050 non-null   float64
#  3   Units Sold  1050 non-null   float64
#  4   Sale Date   1050 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 41.1+ KB

# %%
sns.boxplot(sales_df['Price'])
# Out:
# <Axes: >

# %%
sns.boxplot(sales_df['Units Sold'])
# Out:
# <Axes: >

# %%
sales_df[sales_df['Price']>2000]
# Out:
#         Product    Region   Price  Units Sold   Sale Date
# 969  Product_15  Region_8  2143.3         5.0  2024-08-27

# %%
sales_df.drop(969,axis=0,inplace=True)

# %%
sns.boxplot(sales_df['Price'])
# Out:
# <Axes: >

# %%
sales_df[sales_df['Units Sold']>17.5]
# Out:
#          Product    Region       Price  Units Sold   Sale Date
# 167   Product_28  Region_6   81.148750        18.0  2022-06-17
# 221    Product_5  Region_5   50.360000        20.0  2022-08-10
# 232   Product_14  Region_3  104.270000        19.0  2022-08-21
# 390   Product_41  Region_3  146.960000        18.0  2023-01-26
# 568   Product_42  Region_1    9.720000        18.0  2023-07-23
# 678    Product_9  Region_3   79.339286        18.0  2023-11-10
# 719   Product_50  Region_4   86.730000        22.0  2023-12-21
# 796   Product_16  Region_2  272.830000        18.0  2024-03-07
# 912   Product_22  Region_8  116.490000        19.0  2024-07-01
# 962   Product_13  Region_7    0.610000        19.0  2024-08-20
# 1006  Product_41  Region_3  146.960000        18.0  2023-01-26

# %%
sales_df.drop(sales_df[sales_df['Units Sold']>17.5].index, axis = 0,inplace=True)

# %%
sales_df[sales_df['Units Sold']>17.5]
# Out:
# Empty DataFrame
# Columns: [Product, Region, Price, Units Sold, Sale Date]
# Index: []

# %%
sns.boxplot(sales_df['Units Sold'])
# Out:
# <Axes: >

# %%
sns.boxplot(sales_df['Price'])
# Out:
# <Axes: >

# %%
sns.lmplot(data = sales_df, x = 'Units Sold', y = 'Price', fit_reg=True)

# %%
sns.histplot(sales_df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
plt.scatter(sales_df[sales_df['Product']], sales_df(sales_df[['Region']])
# Out:
#   Cell In[41], line 1
#     plt.scatter(sales_df[sales_df['Product']], sales_df(sales_df[['Region']])
#                                                                              ^
# SyntaxError: incomplete input

# %%
grouped = sales_df.groupby(['Product', 'Region']).size().unstack()

# %%
grouped.plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='Product'>

# %%
sns.boxplot(x='Units Sold', y='Region', data=sales_df)
# Out:
# <Axes: xlabel='Units Sold', ylabel='Region'>

# %%
sns.boxplot(x='Price', y='Product', data=sales_df)
# Out:
# <Axes: xlabel='Price', ylabel='Product'>

# %%
sns.histplot(sales_df['Region'])
# Out:
# <Axes: xlabel='Region', ylabel='Count'>

# %%
sns.histplot(sales_df['Product'])
# Out:
# <Axes: xlabel='Product', ylabel='Count'>

# %%
grouped = sales_df['Product'].value_counts()

# %%
grouped = sales_df['Product'].value_counts()

# %%
plt.pie(grouped, labels=grouped.index, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x285921890>,
#   <matplotlib.patches.Wedge at 0x2862f4610>,
#   <matplotlib.patches.Wedge at 0x285899e90>,
#   <matplotlib.patches.Wedge at 0x2862e6310>,
#   <matplotlib.patches.Wedge at 0x2862f8290>,
#   <matplotlib.patches.Wedge at 0x2862f9bd0>,
#   <matplotlib.patches.Wedge at 0x2862fb750>,
#   <matplotlib.patches.Wedge at 0x2862fd510>,
#   <matplotlib.patches.Wedge at 0x2862f8390>,
#   <matplotlib.patches.Wedge at 0x2862ff910>,
#   <matplotlib.patches.Wedge at 0x286345190>,
#   <matplotlib.patches.Wedge at 0x2863467d0>,
#   <matplotlib.patches.Wedge at 0x286347f10>,
#   <matplotlib.patches.Wedge at 0x286351650>,
#   <matplotlib.patches.Wedge at 0x286352c50>,
#   <matplotlib.patches.Wedge at 0x286364350>,
#   <matplotlib.patches.Wedge at 0x286365990>,
#   <matplotlib.patches.Wedge at 0x286367090>,
#   <matplotlib.patches.Wedge at 0x286374810>,
#   <matplotlib.patches.Wedge at 0x286375fd0>,
#   <matplotlib.patches.Wedge at 0x286377590>,
#   <matplotlib.patches.Wedge at 0x286384c90>,
#   <matplotlib.patches.Wedge at 0x286386290>,
#   <matplotlib.patches.Wedge at 0x286387a10>,
#   <matplotlib.patches.Wedge at 0x286394fd0>,
#   <matplotlib.patches.Wedge at 0x286396650>,
#   <matplotlib.patches.Wedge at 0x286397c90>,
#   <matplotlib.patches.Wedge at 0x2863a5350>,
#   <matplotlib.patches.Wedge at 0x2863a68d0>,
#   <matplotlib.patches.Wedge at 0x2863a7d90>,
#   <matplotlib.patches.Wedge at 0x2863b14d0>,
#   <matplotlib.patches.Wedge at 0x2863b2b10>,
#   <matplotlib.patches.Wedge at 0x2863c0050>,
#   <matplotlib.patches.Wedge at 0x2863c1850>,
#   <matplotlib.patches.Wedge at 0x2842f9510>,
#   <matplotlib.patches.Wedge at 0x284248f10>,
#   <matplotlib.patches.Wedge at 0x2862cc550>,
#   <matplotlib.patches.Wedge at 0x2863c3b50>,
#   <matplotlib.patches.Wedge at 0x2863d4e50>,
#   <matplotlib.patches.Wedge at 0x2863d6310>,
#   <matplotlib.patches.Wedge at 0x2863d7a10>,
#   <matplotlib.patches.Wedge at 0x2863e4f90>,
#   <matplotlib.patches.Wedge at 0x2863e6610>,
#   <matplotlib.patches.Wedge at 0x2863e7c10>,
#   <matplotlib.patches.Wedge at 0x2863f91d0>,
#   <matplotlib.patches.Wedge at 0x2863fa850>,
#   <matplotlib.patches.Wedge at 0x2863fbd90>,
#   <matplotlib.patches.Wedge at 0x286409390>,
#   <matplotlib.patches.Wedge at 0x28640a950>,
#   <matplotlib.patches.Wedge at 0x28640bd50>,
#   <matplotlib.patches.Wedge at 0x2864156d0>],
#  [Text(1.0469821377919055, 0.3373846516139874, 'Other'),
#   Text(0.8354728261812573, 0.7155313806624438, 'Product_45'),
#   Text(0.7053647213721864, 0.8440738177692387, 'Product_5'),
#   Text(0.5586268567385801, 0.9475948685648176, 'Product_33'),
#   Text(0.40010363820809725, 1.0246546143421422, 'Product_1'),
#   Text(0.2410621475248828, 1.0732609379972289, 'Product_30'),
#   Text(0.08315165633662444, 1.09685268019387, 'Product_13'),
#   Text(-0.07318915617171923, 1.0975624571835865, 'Product_29'),
#   Text(-0.22479354751584396, 1.0767858937575483, 'Product_48'),
#   Text(-0.372047801554873, 1.0351716926955576, 'Product_43'),
#   Text(-0.5121022981332989, 0.9735251595344592, 'Product_4'),
#   Text(-0.6395409485205079, 0.8949789802925482, 'Product_40'),
#   Text(-0.7527105285980478, 0.8021389282023704, 'Product_23'),
#   Text(-0.8525511422819647, 0.695094633696533, 'Product_31'),
#   Text(-0.9355479952920238, 0.5785757932242548, 'Product_37'),
#   Text(-0.9999655997781345, 0.4583326294956054, 'Product_19'),
#   Text(-1.047998458203362, 0.3342143497867447, 'Product_46'),
#   Text(-1.0806902623526107, 0.20520369601019775, 'Product_44'),
#   Text(-1.0975624554704702, 0.07318918186202278, 'Product_50'),
#   Text(-1.0983680551035315, -0.0598967071556192, 'Product_17'),
#   Text(-1.083671731385159, -0.18882684818820653, 'Product_39'),
#   Text(-1.054843428292205, -0.31193804158638294, 'Product_15'),
#   Text(-1.012077734411002, -0.4309276731767101, 'Product_10'),
#   Text(-0.9559397024991126, -0.5442235617702602, 'Product_35'),
#   Text(-0.887171070778394, -0.6503287562255864, 'Product_2'),
#   Text(-0.8066804625274837, -0.7478413143016672, 'Product_42'),
#   Text(-0.7155313806624439, -0.8354728261812572, 'Product_14'),
#   Text(-0.6149281559302551, -0.9120654379178152, 'Product_6'),
#   Text(-0.5062000343782863, -0.9766071498793268, 'Product_16'),
#   Text(-0.3938938906140917, -1.0270577407998511, 'Product_7'),
#   Text(-0.27987431010050173, -1.0637999673555965, 'Product_20'),
#   Text(-0.1658273965784654, -1.0874287445823787, 'Product_34'),
#   Text(-0.05324700460783384, -1.0987104971284718, 'Product_41'),
#   Text(0.059896732864778625, -1.0983680537015474, 'Product_25'),
#   Text(0.16911789052568427, -1.0869218643049476, 'Product_32'),
#   Text(0.2734299298326792, -1.0654745766425853, 'Product_27'),
#   Text(0.3751791877603514, -1.0340408971948272, 'Product_28'),
#   Text(0.4734119972988866, -0.9929154449465872, 'Product_8'),
#   Text(0.5672076501144226, -0.9424836771274475, 'Product_24'),
#   Text(0.6530108923967548, -0.8851987202945981, 'Product_22'),
#   Text(0.7305843879459175, -0.8223420529741193, 'Product_21'),
#   Text(0.7998571401606666, -0.7551347928244335, 'Product_11'),
#   Text(0.8609035414412883, -0.6847226389815427, 'Product_38'),
#   Text(0.915770978653803, -0.6093960244828122, 'Product_18'),
#   Text(0.964065651672266, -0.5296955911329917, 'Product_9'),
#   Text(1.0040858915300976, -0.44923437360715057, 'Product_36'),
#   Text(1.0362929924909683, -0.36891304356733473, 'Product_26'),
#   Text(1.062086370426562, -0.2863084730742913, 'Product_49'),
#   Text(1.0813063874900888, -0.20193191023989823, 'Product_12'),
#   Text(1.0938340890356333, -0.11630557021736594, 'Product_47'),
#   Text(1.0993904467991185, -0.036614826052225456, 'Product_3')],
#  [Text(0.571081166068312, 0.18402799178944765, '9.9%'),
#   Text(0.4557124506443221, 0.39028984399769656, '2.7%'),
#   Text(0.384744393475738, 0.4604039006014029, '2.6%'),
#   Text(0.30470555822104367, 0.5168699283080823, '2.6%'),
#   Text(0.2182383481135076, 0.5589025169138957, '2.5%'),
#   Text(0.13148844410448152, 0.5854150570893976, '2.3%'),
#   Text(0.045355448910886054, 0.5982832801057472, '2.3%'),
#   Text(-0.039921357911846846, 0.598670431191047, '2.2%'),
#   Text(-0.12261466228136941, 0.58733776023139, '2.2%'),
#   Text(-0.20293516448447615, 0.5646391051066677, '2.2%'),
#   Text(-0.2793285262545266, 0.5310137233824322, '2.2%'),
#   Text(-0.34884051737482247, 0.4881703528868444, '2.1%'),
#   Text(-0.41056937923529874, 0.43753032447402024, '2.1%'),
#   Text(-0.46502789579016246, 0.37914252747083615, '2.1%'),
#   Text(-0.5102989065229221, 0.31558679630413894, '2.0%'),
#   Text(-0.5454357816971642, 0.249999616088512, '1.9%'),
#   Text(-0.5716355226563791, 0.18229873624731527, '1.9%'),
#   Text(-0.5894674158286967, 0.11192928873283513, '1.9%'),
#   Text(-0.59867043025662, 0.03992137192473969, '1.9%'),
#   Text(-0.5991098482382898, -0.03267093117579229, '1.9%'),
#   Text(-0.5910936716646321, -0.10299646264811264, '1.8%'),
#   Text(-0.5753691427048391, -0.1701480226834816, '1.8%'),
#   Text(-0.5520424005878192, -0.2350514580963873, '1.8%'),
#   Text(-0.5214216559086068, -0.296849215511051, '1.8%'),
#   Text(-0.4839114931518512, -0.3547247761230471, '1.8%'),
#   Text(-0.4400075250149911, -0.4079134441645457, '1.8%'),
#   Text(-0.3902898439976966, -0.45571245064432203, '1.8%'),
#   Text(-0.3354153577801391, -0.4974902388642628, '1.8%'),
#   Text(-0.2761091096608834, -0.5326948090250873, '1.8%'),
#   Text(-0.21485121306223182, -0.560213313163555, '1.7%'),
#   Text(-0.15265871460027364, -0.5802545276485072, '1.7%'),
#   Text(-0.09045130722461749, -0.5931429515903883, '1.6%'),
#   Text(-0.02904382069518209, -0.5992966347973482, '1.6%'),
#   Text(0.03267094519897016, -0.5991098474735713, '1.6%'),
#   Text(0.09224612210491868, -0.5928664714390622, '1.5%'),
#   Text(0.14914359809055228, -0.5811679508959555, '1.5%'),
#   Text(0.20464319332382805, -0.5640223075608147, '1.5%'),
#   Text(0.25822472579939265, -0.5415902426981384, '1.5%'),
#   Text(0.30938599097150327, -0.5140820057058805, '1.5%'),
#   Text(0.35618775948913894, -0.4828356656152353, '1.4%'),
#   Text(0.39850057524322774, -0.44855021071315593, '1.4%'),
#   Text(0.43628571281490897, -0.41189170517696366, '1.3%'),
#   Text(0.4695837498770663, -0.3734850758081142, '1.3%'),
#   Text(0.4995114429020743, -0.3323978315360793, '1.3%'),
#   Text(0.5258539918212359, -0.2889248678907227, '1.3%'),
#   Text(0.5476832135618714, -0.24503693105844573, '1.3%'),
#   Text(0.5652507231768917, -0.2012252964912735, '1.3%'),
#   Text(0.5793198384144882, -0.1561682580405225, '1.3%'),
#   Text(0.5898034840855029, -0.11014467831267175, '1.3%'),
#   Text(0.5966367758376181, -0.06343940193674505, '1.3%'),
#   Text(0.5996675164358828, -0.01997172330121388, '1.1%')])

# %%
sales_df['Revenue'] = sales_df['Price'] * sales_df['Units Sold']
# Out:
#       Product    Region   Price  Units Sold   Sale Date  Revenue
# 0       Other  Region_6   75.96        10.0  2022-01-01   759.60
# 1       Other  Region_1  175.78         8.0  2022-01-02  1406.24
# 2  Product_46  Region_3   20.43        12.0  2022-01-03   245.16
# 3  Product_36  Region_1   12.77        10.0  2022-01-04   127.70
# 4  Product_17  Region_6  125.69         6.0  2022-01-05   754.14

# %%
sns.boxplot(x='Revenue', y='Region', data=sales_df)
# Out:
# <Axes: xlabel='Revenue', ylabel='Region'>

# %%
sns.histplot(sales_df['Revenue'])
# Out:
# <Axes: xlabel='Revenue', ylabel='Count'>

# %%
plt.figure(figsize=(10, 10))
sns.histplot(data=sales_df, x='Region', y='Revenue')
plt.tight_layout()
plt.show()

# %% [markdown]
# END
